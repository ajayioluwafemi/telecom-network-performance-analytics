# %% [markdown]
# # 03 — Churn Prediction Model
#
# **Goal:** build a model that scores each customer with their probability of churning, so the retention team can prioritise calls.
#
# **Approach:** logistic regression first (interpretable baseline), then random forest (usually beats logistic on this dataset). Compare with ROC-AUC.
#
# **Output:** a CSV of `customer_id, churn_probability` for the highest-risk 500 customers — that's the retention team's call list.

# %% [markdown]
# ## 1. Setup

# %%
# TODO: imports
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler
# from sklearn.linear_model import LogisticRegression
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.metrics import (roc_auc_score, roc_curve, classification_report,
#                              confusion_matrix, ConfusionMatrixDisplay)

# %%
# TODO: load ../data/processed/telecom_clean.csv into df

# %% [markdown]
# ## 2. Feature engineering
#
# Decisions to make explicit:
# - Drop `customer_id` from features but keep it as a key for the final scoring output.
# - One-hot encode all categorical columns (Contract, InternetService, PaymentMethod, etc.)
# - Scale `tenure`, `MonthlyCharges`, `TotalCharges` for the logistic regression. (Trees don't need scaling.)

# %%
# TODO: separate target — y = df['churn_flag']
# TODO: drop ['customer_id', 'churn', 'churn_flag'] from df to make X
# TODO: X = pd.get_dummies(X, drop_first=True)
# TODO: print X.shape

# %% [markdown]
# ## 3. Train/test split

# %%
# TODO: train_test_split with stratify=y, test_size=0.2, random_state=42

# %% [markdown]
# ## 4. Model 1 — Logistic Regression (baseline)

# %%
# TODO: scale X_train and X_test with StandardScaler
# TODO: fit LogisticRegression(max_iter=1000)
# TODO: predict probabilities on test set
# TODO: print ROC-AUC and classification_report

# %% [markdown]
# ## 5. Model 2 — Random Forest

# %%
# TODO: fit RandomForestClassifier(n_estimators=200, max_depth=10, random_state=42, class_weight='balanced')
# TODO: predict probabilities, print ROC-AUC and classification_report

# %% [markdown]
# ## 6. Compare the two models

# %%
# TODO: plot ROC curves for both models on one axis
# TODO: save figure to ../images/roc_comparison.png

# %%
# TODO: confusion matrix for the winning model — use ConfusionMatrixDisplay
# TODO: save to ../images/confusion_matrix.png

# %% [markdown]
# ## 7. Feature importance
#
# Pull the top 15 features from the random forest. This is what you'd brief to the business — "these are the levers".

# %%
# TODO: feat_imp = pd.Series(rf.feature_importances_, index=X.columns).sort_values(ascending=False).head(15)
# TODO: bar chart of feat_imp
# TODO: save figure

# %% [markdown]
# ## 8. Score every customer and export the call list
#
# This is the deliverable that goes to the retention team.

# %%
# TODO: predict probabilities on the FULL X (not just test) — be honest about leakage in markdown,
#       OR re-fit on full data first. State which.
# TODO: build output df: customer_id, monthly_charges, contract, churn_probability
# TODO: sort by churn_probability desc, take top 500
# TODO: write to ../data/processed/retention_call_list.csv

# %% [markdown]
# ## 9. Model summary
#
# _Replace this cell with your write-up:_
#
# - Best model: **____** (ROC-AUC = **__**)
# - Top 3 features driving churn: **____**, **____**, **____**
# - The top-500 call list represents **__** % of total predicted churners and **$__** in monthly recurring revenue
# - Recommended next step: A/B test a retention offer on a random half of this list
