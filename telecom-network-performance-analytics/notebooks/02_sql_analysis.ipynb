# %% [markdown]
# # 02 — SQL Analysis
#
# **Goal:** run the queries from `sql/churn_analysis.sql` against the SQLite warehouse and present the results in a notebook so a recruiter can read them without opening a SQL client.
#
# **Why a separate notebook:** in a real analyst job, your SQL skills are tested separately from your Python skills. Keeping them in their own file shows you can think in SQL.
#
# **Prereq:** run `python src/load_to_sqlite.py` first to build `data/processed/telecom.db`.

# %%
# TODO: import sqlite3, pandas as pd
# TODO: open a connection — conn = sqlite3.connect('../data/processed/telecom.db')
# TODO: define a helper — def run(sql): return pd.read_sql_query(sql, conn)

# %% [markdown]
# ## Q1 — Headline churn rate

# %%
# TODO: paste Q1 from churn_analysis.sql, wrap in run("""..."""), display result

# %% [markdown]
# ## Q2 — Churn by contract type

# %%
# TODO: paste Q2, run, display

# %% [markdown]
# ## Q3 — Churn by internet service
#
# _Repeat for Q4 through Q10. For each query, add a 1-sentence interpretation under the result._

# %%
# TODO: Q3

# %%
# TODO: Q4 — tenure cohort

# %%
# TODO: Q5 — revenue at risk

# %%
# TODO: Q6 — tech support effect

# %%
# TODO: Q7 — payment method

# %%
# TODO: Q8 — danger zone cohort

# %%
# TODO: Q9 — top 20 lost high-MRR customers

# %%
# TODO: Q10 — tenure x contract heatmap data
# TODO: pivot the result and show as a heatmap with seaborn

# %%
# TODO: conn.close()
